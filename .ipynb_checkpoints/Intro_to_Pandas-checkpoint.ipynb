# %%
import pandas as pd
df = pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.tail(20)
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 780  710  PumpkabooAverage Size    Ghost   Grass    335   49      66       70
# 781  710    PumpkabooSmall Size    Ghost   Grass    335   44      66       70
# 782  710    PumpkabooLarge Size    Ghost   Grass    335   54      66       70
# 783  710    PumpkabooSuper Size    Ghost   Grass    335   59      66       70
# 784  711  GourgeistAverage Size    Ghost   Grass    494   65      90      122
# 785  711    GourgeistSmall Size    Ghost   Grass    494   55      85      122
# 786  711    GourgeistLarge Size    Ghost   Grass    494   75      95      122
# 787  711    GourgeistSuper Size    Ghost   Grass    494   85     100      122
# 788  712               Bergmite      Ice     NaN    304   55      69       85
# 789  713                Avalugg      Ice     NaN    514   95     117      184
# 790  714                 Noibat   Flying  Dragon    245   40      30       35
# ...

# %% [markdown]
# ## Reading data in pandas

# %%
# Read Headers
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Read each column
df['Name'][:15]
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# 11                    Blastoise
# 12      BlastoiseMega Blastoise
# 13                     Caterpie
# 14                      Metapod
# Name: Name, dtype: object

# %%
df[['Name', 'Type 1', 'Type 2', 'Generation']][:30]
# Out:
#                          Name  Type 1  Type 2  Generation
# 0                   Bulbasaur   Grass  Poison           1
# 1                     Ivysaur   Grass  Poison           1
# 2                    Venusaur   Grass  Poison           1
# 3       VenusaurMega Venusaur   Grass  Poison           1
# 4                  Charmander    Fire     NaN           1
# 5                  Charmeleon    Fire     NaN           1
# 6                   Charizard    Fire  Flying           1
# 7   CharizardMega Charizard X    Fire  Dragon           1
# 8   CharizardMega Charizard Y    Fire  Flying           1
# 9                    Squirtle   Water     NaN           1
# 10                  Wartortle   Water     NaN           1
# 11                  Blastoise   Water     NaN           1
# 12    BlastoiseMega Blastoise   Water     NaN           1
# 13                   Caterpie     Bug     NaN           1
# 14                    Metapod     Bug     NaN           1
# ...

# %%
# Read Each row
print(df.iloc[:4])
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
print(df.loc[df['Type 1'] == 'Grass'].head(5))
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                Ivysaur  Grass  Poison    405  60      62       63
# 2    3               Venusaur  Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 48  43                 Oddish  Grass  Poison    320  45      50       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 48       75       65     30           1      False

# %%
print(df.loc[df['Type 1'] == 'Grass'].tail(5))
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 718  650     Chespin  Grass       NaN    313   56      61       65       48
# 719  651   Quilladin  Grass       NaN    405   61      78       95       56
# 720  652  Chesnaught  Grass  Fighting    530   88     107      122       74
# 740  672      Skiddo  Grass       NaN    350   66      65       48       62
# 741  673      Gogoat  Grass       NaN    531  123     100       62       97
#
#      Sp. Def  Speed  Generation  Legendary
# 718       45     38           6      False
# 719       58     57           6      False
# 720       75     64           6      False
# 740       57     52           6      False
# 741       81     68           6      False

# %%
print(df.loc[(df['Type 1'] == 'Fire') & (df['Generation'] == 3)])
# Out:
#        #                   Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 276  255                Torchic   Fire       NaN    310  45      60       40
# 277  256              Combusken   Fire  Fighting    405  60      85       60
# 278  257               Blaziken   Fire  Fighting    530  80     120       70
# 279  257  BlazikenMega Blaziken   Fire  Fighting    630  80     160       80
# 352  322                  Numel   Fire    Ground    305  60      60       40
# 353  323               Camerupt   Fire    Ground    460  70     100       70
# 354  323  CameruptMega Camerupt   Fire    Ground    560  70     120      100
# 355  324                Torkoal   Fire       NaN    470  70      85      140
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 276       70       50     45           3      False
# 277       85       60     55           3      False
# 278      110       70     80           3      False
# 279      130       80    100           3      False
# ...

# %%
# Read a specific location(R,C)
print(df.iloc[2][1])
print(df.iloc[2,1])
print(df.loc[2,'Name']) #loc is used with row name and column name
# Out:
# Venusaur
# Venusaur
# Venusaur

# %% [markdown]
# ## Describe and Sorting

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'])
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja    Bug   Ghost    236    1      90       45       30
# 230  213    Shuckle    Bug    Rock    505   20      10      230       10
# 462  415     Combee    Bug  Flying    244   30      30       42       30
# 603  543   Venipede    Bug  Poison    260   30      45       59       30
# 314  290    Nincada    Bug  Ground    266   31      45       90       30
# ..   ...        ...    ...     ...    ...  ...     ...      ...      ...
# 142  131     Lapras  Water     Ice    535  130      85       80       85
# 145  134   Vaporeon  Water     NaN    525  130      65       60      110
# 350  320    Wailmer  Water     NaN    400  130      70       35       70
# 655  594  Alomomola  Water     NaN    470  165      75       80       40
# 351  321    Wailord  Water     NaN    500  170      90       45       90
#
#      Sp. Def  Speed  Generation  Legendary
# 316       30     40           3      False
# ...

# %%
df.sort_values('HP', ascending = False)
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 381  349     Feebas    Water    NaN    200   20      15       20       10
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('HP', ascending = False)[:50]
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 261  242                Blissey    Normal       NaN    540  255      10
# 121  113                Chansey    Normal       NaN    450  250       5
# 217  202              Wobbuffet   Psychic       NaN    405  190      33
# 351  321                Wailord     Water       NaN    500  170      90
# 655  594              Alomomola     Water       NaN    470  165      75
# 155  143                Snorlax    Normal       NaN    540  160     110
# 473  426               Drifblim     Ghost    Flying    498  150      80
# 313  289                Slaking    Normal       NaN    670  150     160
# 544  487  GiratinaAltered Forme     Ghost    Dragon    680  150     100
# 545  487   GiratinaOrigin Forme     Ghost    Dragon    680  150     120
# 321  297               Hariyama  Fighting       NaN    474  144     120
# 45    40             Wigglytuff    Normal     Fairy    435  140      70
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending = [True, False])
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 520  469                  Yanmega    Bug    Flying    515  86      76
# 698  637                Volcarona    Bug      Fire    550  85      60
# 231  214                Heracross    Bug  Fighting    500  80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug       NaN    495  80      70
# ..   ...                      ...    ...       ...    ...  ..     ...
# 106   98                   Krabby  Water       NaN    325  30     105
# 125  116                   Horsea  Water       NaN    295  30      40
# 129  120                   Staryu  Water       NaN    340  30      45
# 139  129                 Magikarp  Water       NaN    200  20      10
# 381  349                   Feebas  Water       NaN    200  20      15
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520       86      116       56     95           4      False
# ...

# %% [markdown]
# ## Making Changes to the data

# %%
df['Total_attacks'] = df['Attack'] + df['Sp. Atk']

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_attacks
# 0       65       65     45           1      False            114
# ...

# %%
df.drop(columns = 'Total_attacks')
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df = df.drop(columns = 'Total_attacks')
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df['Total_attacks'] = df.iloc[:, [6, 8]].sum(axis = 1)
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_attacks
# 0       65       65     45           1      False            114
# ...

# %%
#Rearranging columns
cols = list(df.columns)
df = df[cols[:10] + [cols[-1]] + cols[10:13]]
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Total_attacks  Speed  Generation  Legendary
# 0       65       65            114     45           1      False
# ...

# %% [markdown]
# ## Saving our data (CSV, Excel, txt etc)

# %%
df.to_csv('modified_pokemon_data.csv', index = False)

# %%
df.to_excel('modified_pokemon_data.xlsx', index = False)

# %%
df.to_csv('modified_pokemon_data.txt', sep='\t', index=False)

# %% [markdown]
# ## Filtering data

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
df.loc[((df['Type 1'] == 'Fire') & (df['Type 2'] == 'Dragon')) | ((df['Type 1'] == 'Dragon') & (df['Type 2'] == 'Fire'))]
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 706  643                   Reshiram  Dragon    Fire    680  100     120
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        111      130       85    100           1      False
# 706      100      150      120     90           5       True

# %%
df.loc[((df['Type 1'] == 'Fire') & (df['Type 2'] == 'Fighting')) | ((df['Type 1'] == 'Fighting') & (df['Type 2'] == 'Fire'))]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 277  256              Combusken   Fire  Fighting    405   60      85       60
# 278  257               Blaziken   Fire  Fighting    530   80     120       70
# 279  257  BlazikenMega Blaziken   Fire  Fighting    630   80     160       80
# 436  391               Monferno   Fire  Fighting    405   64      78       52
# 437  392              Infernape   Fire  Fighting    534   76     104       71
# 558  499                Pignite   Fire  Fighting    418   90      93       55
# 559  500                 Emboar   Fire  Fighting    528  110     123       65
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 277       85       60     55           3      False
# 278      110       70     80           3      False
# 279      130       80    100           3      False
# 436       78       52     81           4      False
# 437      104       71    108           4      False
# ...

# %%
df.loc[((df['Type 1'] == 'Dragon') & (df['Type 2'] == 'Flying')) | ((df['Type 1'] == 'Flying') & (df['Type 2'] == 'Dragon'))]
# Out:
#        #                     Name  Type 1  Type 2  Total   HP  Attack  \
# 161  149                Dragonite  Dragon  Flying    600   91     134
# 365  334                  Altaria  Dragon  Flying    490   75      70
# 408  373                Salamence  Dragon  Flying    600   95     135
# 409  373  SalamenceMega Salamence  Dragon  Flying    700   95     145
# 425  384                 Rayquaza  Dragon  Flying    680  105     150
# 426  384    RayquazaMega Rayquaza  Dragon  Flying    780  105     180
# 790  714                   Noibat  Flying  Dragon    245   40      30
# 791  715                  Noivern  Flying  Dragon    535   85      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 161       95      100      100     80           1      False
# 365       90       70      105     80           3      False
# 408       80      110       80    100           3      False
# 409      130      120       90    120           3      False
# ...

# %%
df.loc[(df['Type 1'] == 'Fire') | (df['Type 2'] == 'Dragon')]
# Out:
#        #                       Name  Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander    Fire     NaN    309  39      52
# 5      5                 Charmeleon    Fire     NaN    405  58      64
# 6      6                  Charizard    Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X    Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y    Fire  Flying    634  78     104
# ..   ...                        ...     ...     ...    ...  ..     ...
# 766  696                     Tyrunt    Rock  Dragon    362  58      89
# 767  697                  Tyrantrum    Rock  Dragon    521  82     121
# 790  714                     Noibat  Flying  Dragon    245  40      30
# 791  715                    Noivern  Flying  Dragon    535  85      70
# 799  721                  Volcanion    Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Type 2'] == 'Water')]
# Out:
#        #       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 799  721  Volcanion   Fire  Water    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 799       90     70           6       True

# %%
new_df = df.loc[((df['Type 1'] == 'Water') & (df['Type 2'] == 'Dragon')) | ((df['Type 2'] == 'Water') & (df['Type 1'] == 'Dragon'))]
new_df
# Out:
#        #     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 249  230  Kingdra  Water  Dragon    540  75      95       95       95
# 541  484   Palkia  Water  Dragon    680  90     120      100      150
#
#      Sp. Def  Speed  Generation  Legendary
# 249       95     85           2      False
# 541      120    100           4       True

# %%
new_df = df.loc[((df['Type 1'] == 'Electric') & (df['Type 2'] == 'Dragon')) | ((df['Type 2'] == 'Electric') & (df['Type 1'] == 'Dragon'))]
new_df
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 196  181  AmpharosMega Ampharos  Electric    Dragon    610   90      95
# 707  644                 Zekrom    Dragon  Electric    680  100     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 196      105      165      110     45           2      False
# 707      120      120      100     90           5       True

# %%
new_df = df.loc[((df['Type 1'] == 'Steel') & (df['Type 2'] == 'Dragon')) | ((df['Type 2'] == 'Steel') & (df['Type 1'] == 'Dragon'))]
new_df
# Out:
#        #    Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 540  483  Dialga  Steel  Dragon    680  100     120      120      150
#
#      Sp. Def  Speed  Generation  Legendary
# 540      100     90           4       True

# %%
new_df = df.loc[((df['Type 1'] == 'Ground') & (df['Type 2'] == 'Dragon')) | ((df['Type 2'] == 'Ground') & (df['Type 1'] == 'Dragon'))]
new_df
# Out:
#        #                   Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 360  329                Vibrava  Ground  Dragon    340   50      70       50
# 361  330                 Flygon  Ground  Dragon    520   80     100       80
# 491  443                  Gible  Dragon  Ground    300   58      70       45
# 492  444                 Gabite  Dragon  Ground    410   68      90       65
# 493  445               Garchomp  Dragon  Ground    600  108     130       95
# 494  445  GarchompMega Garchomp  Dragon  Ground    700  108     170      115
# 794  718       Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 360       50       50     70           3      False
# 361       80       80    100           3      False
# 491       40       45     42           4      False
# 492       50       55     82           4      False
# 493       80       85    102           4      False
# ...

# %%
new_df = df.loc[((df['Type 1'] == 'Ground') & (df['Type 2'] == 'Rock')) | ((df['Type 2'] == 'Ground') & (df['Type 1'] == 'Rock'))]
new_df
# Out:
#        #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 80    74    Geodude    Rock  Ground    300   40      80      100       30
# 81    75   Graveler    Rock  Ground    390   55      95      115       45
# 82    76      Golem    Rock  Ground    495   80     120      130       55
# 103   95       Onix    Rock  Ground    385   35      45      160       30
# 119  111    Rhyhorn  Ground    Rock    345   80      85       95       30
# 120  112     Rhydon  Ground    Rock    485  105     130      120       45
# 265  246   Larvitar    Rock  Ground    300   50      64       50       45
# 266  247    Pupitar    Rock  Ground    410   70      84       70       65
# 515  464  Rhyperior  Ground    Rock    535  115     140      130       55
#
#      Sp. Def  Speed  Generation  Legendary
# 80        30     20           1      False
# 81        45     35           1      False
# 82        65     45           1      False
# 103       45     70           1      False
# ...

# %%
new_df = df.loc[((df['Type 1'] == 'Flying') & (df['Type 2'] == 'Dragon')) | ((df['Type 2'] == 'Flying') & (df['Type 1'] == 'Dragon'))]
new_df
# Out:
#        #                     Name  Type 1  Type 2  Total   HP  Attack  \
# 161  149                Dragonite  Dragon  Flying    600   91     134
# 365  334                  Altaria  Dragon  Flying    490   75      70
# 408  373                Salamence  Dragon  Flying    600   95     135
# 409  373  SalamenceMega Salamence  Dragon  Flying    700   95     145
# 425  384                 Rayquaza  Dragon  Flying    680  105     150
# 426  384    RayquazaMega Rayquaza  Dragon  Flying    780  105     180
# 790  714                   Noibat  Flying  Dragon    245   40      30
# 791  715                  Noivern  Flying  Dragon    535   85      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 161       95      100      100     80           1      False
# 365       90       70      105     80           3      False
# 408       80      110       80    100           3      False
# 409      130      120       90    120           3      False
# ...

# %%
new_df.to_csv('filtered.csv', index = False)

# %%
new_df = new_df.drop(columns = ['index'])

# %%
new_df
# Out:
#      #                     Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0  149                Dragonite  Dragon  Flying    600   91     134       95
# 1  334                  Altaria  Dragon  Flying    490   75      70       90
# 2  373                Salamence  Dragon  Flying    600   95     135       80
# 3  373  SalamenceMega Salamence  Dragon  Flying    700   95     145      130
# 4  384                 Rayquaza  Dragon  Flying    680  105     150       90
# 5  384    RayquazaMega Rayquaza  Dragon  Flying    780  105     180      100
# 6  714                   Noibat  Flying  Dragon    245   40      30       35
# 7  715                  Noivern  Flying  Dragon    535   85      70       80
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1       70      105     80           3      False
# 2      110       80    100           3      False
# 3      120       90    120           3      False
# ...

# %% [markdown]
# ## Reset Index

# %%
new_df = df.loc[((df['Type 1'] == 'Ground') & (df['Type 2'] == 'Rock')) | ((df['Type 2'] == 'Ground') & (df['Type 1'] == 'Rock'))]
new_df
# Out:
#        #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 80    74    Geodude    Rock  Ground    300   40      80      100       30
# 81    75   Graveler    Rock  Ground    390   55      95      115       45
# 82    76      Golem    Rock  Ground    495   80     120      130       55
# 103   95       Onix    Rock  Ground    385   35      45      160       30
# 119  111    Rhyhorn  Ground    Rock    345   80      85       95       30
# 120  112     Rhydon  Ground    Rock    485  105     130      120       45
# 265  246   Larvitar    Rock  Ground    300   50      64       50       45
# 266  247    Pupitar    Rock  Ground    410   70      84       70       65
# 515  464  Rhyperior  Ground    Rock    535  115     140      130       55
#
#      Sp. Def  Speed  Generation  Legendary
# 80        30     20           1      False
# 81        45     35           1      False
# 82        65     45           1      False
# 103       45     70           1      False
# ...

# %%
new_df.reset_index()
# Out:
#    index    #       Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0     80   74    Geodude    Rock  Ground    300   40      80      100
# 1     81   75   Graveler    Rock  Ground    390   55      95      115
# 2     82   76      Golem    Rock  Ground    495   80     120      130
# 3    103   95       Onix    Rock  Ground    385   35      45      160
# 4    119  111    Rhyhorn  Ground    Rock    345   80      85       95
# 5    120  112     Rhydon  Ground    Rock    485  105     130      120
# 6    265  246   Larvitar    Rock  Ground    300   50      64       50
# 7    266  247    Pupitar    Rock  Ground    410   70      84       70
# 8    515  464  Rhyperior  Ground    Rock    535  115     140      130
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       30       30     20           1      False
# 1       45       45     35           1      False
# 2       55       65     45           1      False
# 3       30       45     70           1      False
# ...

# %%
new_df.reset_index(drop = True, inplace = True)

# %%
new_df
# Out:
#      #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0   74    Geodude    Rock  Ground    300   40      80      100       30
# 1   75   Graveler    Rock  Ground    390   55      95      115       45
# 2   76      Golem    Rock  Ground    495   80     120      130       55
# 3   95       Onix    Rock  Ground    385   35      45      160       30
# 4  111    Rhyhorn  Ground    Rock    345   80      85       95       30
# 5  112     Rhydon  Ground    Rock    485  105     130      120       45
# 6  246   Larvitar    Rock  Ground    300   50      64       50       45
# 7  247    Pupitar    Rock  Ground    410   70      84       70       65
# 8  464  Rhyperior  Ground    Rock    535  115     140      130       55
#
#    Sp. Def  Speed  Generation  Legendary
# 0       30     20           1      False
# 1       45     35           1      False
# 2       65     45           1      False
# 3       45     70           1      False
# ...

# %% [markdown]
# ## Regex Filtering

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Dragon')]
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 4      4                 Charmander    Fire     NaN    309   39      52
# 5      5                 Charmeleon    Fire     NaN    405   58      64
# 6      6                  Charizard    Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y    Fire  Flying    634   78     104
# ..   ...                        ...     ...     ...    ...  ...     ...
# 774  704                      Goomy  Dragon     NaN    300   45      50
# 775  705                    Sliggoo  Dragon     NaN    452   68      75
# 776  706                     Goodra  Dragon     NaN    600   90     100
# 794  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 799  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'].str.contains('fire|dragon', case = False)]
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 4      4                 Charmander    Fire     NaN    309   39      52
# 5      5                 Charmeleon    Fire     NaN    405   58      64
# 6      6                  Charizard    Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y    Fire  Flying    634   78     104
# ..   ...                        ...     ...     ...    ...  ...     ...
# 774  704                      Goomy  Dragon     NaN    300   45      50
# 775  705                    Sliggoo  Dragon     NaN    452   68      75
# 776  706                     Goodra  Dragon     NaN    600   90     100
# 794  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 799  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.contains('^pi', case = False)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %%
df.loc[df['Name'].str.contains('pi', case = False)]
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 13    10                 Caterpie       Bug       NaN    195   45      30
# 20    16                   Pidgey    Normal    Flying    251   40      45
# 21    17                Pidgeotto    Normal    Flying    349   63      60
# 22    18                  Pidgeot    Normal    Flying    479   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25                  Pikachu  Electric       NaN    320   35      55
# 42    37                   Vulpix      Fire       NaN    299   38      41
# 76    70               Weepinbell     Grass    Poison    390   65      90
# 84    78                 Rapidash      Fire       NaN    500   65     100
# 136  127                   Pinsir       Bug       NaN    500   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying    600   65     155
# 181  167                 Spinarak       Bug    Poison    250   40      60
# ...

# %% [markdown]
# ## Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = pd.read_csv('modified_pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## Aggregate Statistics (GroupBy)

# %%
df = pd.read_csv('modified_pokemon_data.csv')

# %%
df.groupby('Type 1').mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10224\2210688449.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean()
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# ...

# %%
df.groupby('Type 1').mean().sort_values('Defense', ascending = False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10224\1071828000.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean().sort_values('Defense', ascending = False)
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# ...

# %%
df.groupby('Type 1').mean().sort_values('Attack', ascending = False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10224\988561608.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean().sort_values('Attack', ascending = False)
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# ...

# %%
df.groupby('Type 1').mean().sort_values('HP', ascending = False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10224\49879542.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean().sort_values('HP', ascending = False)
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# ...

# %%
df['count'] = 1
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.groupby('Type 1').count().sort_values('count', ascending = False)['count']
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).count().sort_values('count', ascending = False)['count']
# Out:
# Type 1    Type 2
# Normal    Flying    24
# Grass     Poison    15
# Bug       Flying    14
#           Poison    12
# Ghost     Grass     10
#                     ..
# Fire      Rock       1
# Ice       Ghost      1
# Fire      Dragon     1
# Fighting  Flying     1
# Water     Steel      1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Merge, Join and Concatenate

# %%
import pandas as pd

# %%
df1 = pd.read_csv('dataset1.csv')
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df2 = pd.read_csv('dataset2.csv')
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
df1.merge(df2)
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
pd.merge(df1, df2)
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
pd.merge(df1, df2, how="outer")
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
pd.merge(df1, df2, on="FellowshipID", how="outer")
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y     Age
# 0          1001       Frodo     Hiding       Frodo    50.0
# 1          1002     Samwise  Gardening     Samwise    39.0
# 2          1003     Gandalf     Spells         NaN     NaN
# 3          1004      Pippin  Fireworks         NaN     NaN
# 4          1006         NaN        NaN     Legolas  2931.0
# 5          1007         NaN        NaN      Elrond  6520.0
# 6          1008         NaN        NaN    Barromir    51.0

# %%
pd.merge(df1, df2, on="FellowshipID", how="inner")
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y  Age
# 0          1001       Frodo     Hiding       Frodo   50
# 1          1002     Samwise  Gardening     Samwise   39

# %%
pd.merge(df1, df2, on="FellowshipID", how="left")
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y   Age
# 0          1001       Frodo     Hiding       Frodo  50.0
# 1          1002     Samwise  Gardening     Samwise  39.0
# 2          1003     Gandalf     Spells         NaN   NaN
# 3          1004      Pippin  Fireworks         NaN   NaN

# %%
pd.merge(df1, df2, on="FellowshipID", how="right")
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y   Age
# 0          1001       Frodo     Hiding       Frodo    50
# 1          1002     Samwise  Gardening     Samwise    39
# 2          1006         NaN        NaN     Legolas  2931
# 3          1007         NaN        NaN      Elrond  6520
# 4          1008         NaN        NaN    Barromir    51

# %%
pd.merge(df1, df2, on=["FellowshipID", "FirstName"])
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
pd.merge(df1, df2, on=["FellowshipID", "FirstName"], how="outer")
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
pd.merge(df1, df2, on=["FellowshipID", "FirstName"], how="left")
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
pd.merge(df1, df2, on=["FellowshipID", "FirstName"], how="right")
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %%
pd.merge(df1, df2, how="cross")
# Out:
#     FellowshipID_x FirstName_x     Skills  FellowshipID_y FirstName_y   Age
# 0             1001       Frodo     Hiding            1001       Frodo    50
# 1             1001       Frodo     Hiding            1002     Samwise    39
# 2             1001       Frodo     Hiding            1006     Legolas  2931
# 3             1001       Frodo     Hiding            1007      Elrond  6520
# 4             1001       Frodo     Hiding            1008    Barromir    51
# 5             1002     Samwise  Gardening            1001       Frodo    50
# 6             1002     Samwise  Gardening            1002     Samwise    39
# 7             1002     Samwise  Gardening            1006     Legolas  2931
# 8             1002     Samwise  Gardening            1007      Elrond  6520
# 9             1002     Samwise  Gardening            1008    Barromir    51
# 10            1003     Gandalf     Spells            1001       Frodo    50
# ...

# %%
pd.concat([df1, df2])
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df1, df2], join="inner")
# Out:
#    FellowshipID FirstName
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1003   Gandalf
# 3          1004    Pippin
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1006   Legolas
# 3          1007    Elrond
# 4          1008  Barromir

# %%
pd.concat([df1, df2], join="outer")
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df1, df2], join="outer", axis=1)
# Out:
#    FellowshipID FirstName     Skills  FellowshipID FirstName   Age
# 0        1001.0     Frodo     Hiding          1001     Frodo    50
# 1        1002.0   Samwise  Gardening          1002   Samwise    39
# 2        1003.0   Gandalf     Spells          1006   Legolas  2931
# 3        1004.0    Pippin  Fireworks          1007    Elrond  6520
# 4           NaN       NaN        NaN          1008  Barromir    51

# %% [markdown]
# ## Pandas Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Ice-Cream-Ratings.csv")
df.set_index('Date', inplace = True)
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(grid = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Line Plot

# %%
df.plot(kind = 'line', subplots = True, grid = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(
    kind = 'line',
    xlabel = 'Daily Ratings',
    ylabel = 'Scores',
    title = 'Ice Cream Ratings',
    grid = True
)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %% [markdown]
# ### Bar Plot

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind = 'bar', title = 'Flavor Rating')
# Out:
# <Axes: title={'center': 'Flavor Rating'}, xlabel='Date'>

# %%
df['Texture Rating'].plot(kind = 'bar', title = 'Texture Rating')
# Out:
# <Axes: title={'center': 'Texture Rating'}, xlabel='Date'>

# %%
df['Overall Rating'].plot(kind = 'bar', title = 'Overall Rating')
# Out:
# <Axes: title={'center': 'Overall Rating'}, xlabel='Date'>

# %%
df.plot(kind = 'barh', stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(kind = 'scatter', x = 'Texture Rating', y = 'Overall Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 100)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 100, c = 'Red', grid = True)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# ### Histogram

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Box Plot

# %%
df.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Area Plot

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
#Stacked Area Plot
df.plot.area(stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
#Overlapping Area Plot
df.plot.area(stacked = False)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Pie Plot

# %%
df.plot.pie(y = 'Flavor Rating')
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
df.plot.pie(y = 'Overall Rating')
# Out:
# <Axes: ylabel='Overall Rating'>

# %%
df.plot.pie(subplots = True)
# Out:
# array([<Axes: ylabel='Flavor Rating'>, <Axes: ylabel='Texture Rating'>,
#        <Axes: ylabel='Overall Rating'>], dtype=object)

# %%
df.plot.pie(subplots = True, figsize = (5,5))
